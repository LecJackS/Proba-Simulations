# %% [markdown]
# ### ~

# %%
X <- read.table(file="graduados.txt", sep="")
X
# Out:
#    V1
# 1  3.46
# 2  3.72
# 3  3.95
# 4  3.55
# 5  3.62
# 6  3.80
# 7  3.86
# 8  3.71
# 9  3.56
# 10 3.49
# 11 3.96
# 12 3.90
# 13 3.70
# 14 3.61
# 15 3.72
# 16 3.65
# 17 3.48
# 18 3.87
# 19 3.82
# 20 3.91
# 21 3.69
# 22 3.67
# 23 3.72
# 24 3.66
# 25 3.79
# 26 3.75
# 27 3.93
# 28 3.74
# 29 3.50
# 30 3.83
