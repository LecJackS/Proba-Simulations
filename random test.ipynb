# %%
from scipy.special import comb

# %%
comb(4,2)
# Out:
# 6.0

# %%
def aSub(n):
    return (comb(2*n,n))

# %%
aSub(2)
# Out:
# 6.0

# %%
a1=2

# %%
aSub(1)
# Out:
# 2.0

# %%
for i in range(1,100):
    toProve = 4*aSub(i-1)-2*1/(i-1+1)*aSub(i-1) 
    print(aSub(i), " - ", toProve, " = ", aSub(i)-toProve)
# Out:
# 2.0  -  2.0  =  0.0
# 6.0  -  6.0  =  0.0
# 20.0  -  20.0  =  0.0
# 70.0  -  70.0  =  0.0
# 252.0  -  252.0  =  0.0
# 924.0  -  924.0  =  0.0
# 3432.0  -  3432.0  =  0.0
# 12870.0  -  12870.0  =  0.0
# 48620.0  -  48620.0  =  0.0
# 184756.0  -  184756.0  =  0.0
# 705432.0  -  705432.0  =  0.0
# 2704156.0  -  2704156.0  =  0.0
# 10400600.0  -  10400600.0  =  0.0
# 40116600.0  -  40116600.0  =  0.0
# 155117520.0  -  155117520.0  =  0.0
# 601080390.0  -  601080390.0  =  0.0
# 2333606220.0  -  2333606220.0  =  0.0
# 9075135300.0  -  9075135300.0  =  0.0
# 35345263799.99999  -  35345263800.0  =  -7.62939453125e-06
# 137846528820.00003  -  137846528819.99997  =  6.103515625e-05
# 538257874439.99994  -  538257874440.0001  =  -0.00018310546875
# 2104098963720.0  -  2104098963719.9998  =  0.000244140625
# 8233430727599.999  -  8233430727600.0  =  -0.0009765625
# 32247603683100.0  -  32247603683099.996  =  0.00390625
# 126410606437752.05  -  126410606437752.0  =  0.046875
# ...
